# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\Documents\EDA\Visadataset - Visadataset (1).csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# ***Task***

# %% [markdown]
# - take prevailing wage column
# - caluculate the mean valy prevailing wage
# - calculate the standard deviation of prevailaing vage
# - caluculate the nr : step1- step-2
# - divide the step4/step3

# %%
mean=visa_df["prevailing_wage"].mean()
mean
# Out:
# 74455.81459209183

# %%
std=visa_df["prevailing_wage"].std()
std
# Out:
# 52815.94232687357

# %%
visa_df["prevailing_wage"]
mean=visa_df["prevailing_wage"].mean()
std=visa_df["prevailing_wage"].std()
Nr=visa_df["prevailing_wage"]-wage_std
Nr/wage_std
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 mean=visa_df["prevailing_wage"].mean()
#       3 std=visa_df["prevailing_wage"].std()
# ----> 4 Nr=visa_df["prevailing_wage"]-wage_std
#       5 Nr/wage_std
#
# NameError: name 'wage_std' is not defined

# %%
mean=visa_df["prevailing_wage"].mean()
std=visa_df["prevailing_wage"].std()
Nr=visa_df["prevailing_wage"]-mean
visa_df["prevailing_wage_z"]=Nr/std
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
maxx,minn=visa_df["prevailing_wage"].idxmax(),visa_df["prevailing_wage_z"].idxmax()
minn=visa_df["prevailing_wage"].idxmin(),visa_df["prevailing_wage_z"].idxmin()

maxx,minn
# Out:
# (21077, (20575, 20575))

# %%
***Task-2***
- compare the two columns
- get the maximum value

# %% [markdown]
# **standadscalar**

# %% [markdown]
# - standardscalar same as z-score but by using pacakge
# - it is under sklearn package
# - in the sklearn we have preprocessing
# - read the package
# - save the package
# - apply fit transfrom
# - compare 3 coumns

# %%
from sklearn.preprocessing import standardscaler

ss=standardscaler()
visa_df['prevailing_wage_ss']=ss.fit_transfrom(visa_df[["prevailing_wage_ss"]])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 from sklearn.preprocessing import standardscaler
#       3 ss=standardscaler()
#       4 visa_df['prevailing_wage_ss']=ss.fit_transfrom(visa_df[["prevailing_wage_ss"]])
#
# ImportError: cannot import name 'standardscaler' from 'sklearn.preprocessing' (C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\preprocessing\__init__.py)

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\Documents\EDA\Visadataset - Visadataset (1).csv")
cols=visa_df["prevailing_wage"]
min=visa_df["prevailing_wage"]min()
max=visa_df["prevailing_wage"].max()
