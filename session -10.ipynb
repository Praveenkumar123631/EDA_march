# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **DATA transforemations**
# - Generally data has 3 types of distribution
# - normal distribution 4
# - positive skewed
# - negative skewed
# - All the math concepts developed by assumption as Data frollows Normal distribution

# %% [markdown]
# **step-1**

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\Documents\EDA\Visadataset - Visadataset (1).csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.12345753, 1.23306967, 1.02936292, ..., 0.12651718, 0.90165794,
#        0.37129248])

# %%
plt.hist(exp_data,bins=20,label="exponential")
plt.show()

# %% [markdown]
# **goal**
# **convert exp_data to normal distribution**
# **bins= interval**

# %%
x=2
np.log(x)
# Out:
# 0.6931471805599453

# %%
log_data=np.random.exponential(size=10000)
log_data
# Out:
# array([0.68810052, 0.6010179 , 2.11016392, ..., 0.82798788, 0.904844  ,
#        0.35337358])

# %%
plt.hist(log_data,bins=20,label="logarithm")
plt.show()

# %%
pin=np.log(exp_data)
pin
# Out:
# array([-2.09185807,  0.20950673,  0.02894009, ..., -2.06737719,
#        -0.10352005, -0.99076516])

# %%
plt.hist(pin,bins=20,label="logarithm")
plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(exp_data,bins=20,label='Exponential')
plt.subplot(1,2,2)
plt.hist(pin,bins=20,label='logdata')
# Out:
# (array([1.000e+00, 0.000e+00, 1.000e+00, 0.000e+00, 2.000e+00, 6.000e+00,
#         7.000e+00, 1.500e+01, 2.000e+01, 4.400e+01, 1.060e+02, 2.130e+02,
#         3.490e+02, 8.140e+02, 1.292e+03, 2.010e+03, 2.528e+03, 1.953e+03,
#         5.860e+02, 5.300e+01]),
#  array([-11.51617663, -10.82108288, -10.12598914,  -9.43089539,
#          -8.73580165,  -8.0407079 ,  -7.34561416,  -6.65052042,
#          -5.95542667,  -5.26033293,  -4.56523918,  -3.87014544,
#          -3.17505169,  -2.47995795,  -1.7848642 ,  -1.08977046,
#          -0.39467671,   0.30041703,   0.99551077,   1.69060452,
#           2.38569826]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# ***Recprocal Transformation***

# %%
x=2
1/x
# Out:
# 0.5

# %%
exp_data=np.random.exponential(size=10000)
exp_data
# Out:
# array([0.21095464, 0.60060132, 0.02599756, ..., 3.91902256, 0.76718466,
#        1.49815255])

# %%
reci=1/exp_data

# %%
reci
# Out:
# array([ 4.74035562,  1.66499802, 38.46514245, ...,  0.25516567,
#         1.30346714,  0.66748877])

# %%
plt.subplot(1,2,1)
plt.hist(exp_data,bins=20,label='Exponential')
plt.subplot(1,2,2)
plt.hist(reci,bins=20,label='Reciprocal')
# Out:
# (array([9.974e+03, 1.400e+01, 5.000e+00, 1.000e+00, 3.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00, 1.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([9.58532302e-02, 3.64109700e+02, 7.28123547e+02, 1.09213739e+03,
#         1.45615124e+03, 1.82016509e+03, 2.18417894e+03, 2.54819278e+03,
#         2.91220663e+03, 3.27622048e+03, 3.64023432e+03, 4.00424817e+03,
#         4.36826202e+03, 4.73227586e+03, 5.09628971e+03, 5.46030356e+03,
#         5.82431741e+03, 6.18833125e+03, 6.55234510e+03, 6.91635895e+03,
#         7.28037279e+03]),
#  <BarContainer object of 20 artists>)

# %%
squre_root_data=np=np.sqrt(exp_data)
plt.hist(squre_root_data,bins=20,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# **power transformar**

# %% [markdown]
# - box cox
# - ye-jhonson
# - it is under sklearn preprocessing

# %%
import pandas as pd

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\Downloads\bank+marketing\bank-additional\bank-additional\bank-additional.csv",sep=";")
visa_df
# Out:
#       age          job  marital          education default  housing     loan  \
# 0      30  blue-collar  married           basic.9y      no      yes       no
# 1      39     services   single        high.school      no       no       no
# 2      25     services  married        high.school      no      yes       no
# 3      38     services  married           basic.9y      no  unknown  unknown
# 4      47       admin.  married  university.degree      no      yes       no
# ...   ...          ...      ...                ...     ...      ...      ...
# 4114   30       admin.  married           basic.6y      no      yes      yes
# 4115   39       admin.  married        high.school      no      yes       no
# 4116   27      student   single        high.school      no       no       no
# 4117   58       admin.  married        high.school      no       no       no
# 4118   34   management   single        high.school      no      yes       no
#
# ...

# %%
visa_df=pd.read_csv(r"C:\Users\Admin\Downloads\train_ctrUa4K.csv")
visa_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
